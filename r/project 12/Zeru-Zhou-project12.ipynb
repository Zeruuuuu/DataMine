# %% [markdown]
# # Project 12 -- Zeru Zhou

# %% [markdown]
# **TA Help:** NA
#
#
#
# **Collaboration:** NA
#
# - Get help from Dr. Ward's video

# %% [markdown]
# ## Question 1

# %%
library(data.table)

# %%
liquor <- fread("/depot/datamine/data/iowa_liquor_sales/clean_sample.csv")

# %%
dim(liquor)
# Out:
# [1] 5999999      24

# %%
liquor$Date[1] - liquor$Date[2]
# Out:
# Error in liquor$Date[1] - liquor$Date[2]: non-numeric argument to binary operator
# Traceback:

# %%
liquor$date <- as.Date(liquor$Date, format="%m/%d/%Y")

# %%
class(liquor$date)
# Out:
# [1] "Date"

# %%
head(liquor$date)
# Out:
# [1] "2015-11-20" "2015-11-21" "2015-11-16" "2015-11-04" "2015-11-17"
# [6] "2015-11-11"

# %%
liquor$date[1] - liquor$date[2]
# Out:
# Time difference of -1 days

# %% [markdown]
# We inserted a new column that is in the "Date" class.

# %% [markdown]
# ## Question 2

# %%
liquor$year <- format(liquor$date, "%Y")

# %%
liquor$month <- format(liquor$date, "%m")

# %%
table(liquor$month,liquor$year)
# Out:
#
#        2012   2013   2014   2015
#   01 108290 119072 115816 116038
#   02 114902 110401 109683 116015
#   03 117510 113427 117634 130953
#   04 120966 130008 129591 132087
#   05 140596 130791 120785 124099
#   06 123756 115001 135112 150338
#   07 132524 142773 137450 133481
#   08 140060 124087 126628 130932
#   09 109169 121248 125338 138860
#   10 144372 138849 132034 127839
#   11 123508 109391 114983 128989
#   12 149395 155762 169456      0

# %% [markdown]
# 2012, 2013, 2014, and 2015 are covered in this dataset. All month are covered except for Dec, 2015.

# %% [markdown]
# ## Question 3

# %%
liquor <- fread("/depot/datamine/data/iowa_liquor_sales/clean_sample.csv")

# %%
library(lubridate)
# Out:
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
liquor$date_b <- mdy(liquor$Date)

# %%
liquor$month_b <- month(mdy(liquor$Date))

# %%
liquor$year_b <- year(mdy(liquor$Date))

# %%
table(liquor$month_b,liquor$year_b)
# Out:
#
#        2012   2013   2014   2015
#   1  108290 119072 115816 116038
#   2  114902 110401 109683 116015
#   3  117510 113427 117634 130953
#   4  120966 130008 129591 132087
#   5  140596 130791 120785 124099
#   6  123756 115001 135112 150338
#   7  132524 142773 137450 133481
#   8  140060 124087 126628 130932
#   9  109169 121248 125338 138860
#   10 144372 138849 132034 127839
#   11 123508 109391 114983 128989
#   12 149395 155762 169456      0

# %%
head(liquor)
# Out:
#   Invoice/Item Number Date       Store Number Store Name
# 1 S29198800001        11/20/2015 2191         Keokuk Spirits
# 2 S29195400002        11/21/2015 2205         Ding's Honk And Holler
# 3 S29050300001        11/16/2015 3549         Quicker Liquor Store
# 4 S28867700001        11/04/2015 2513         Hy-Vee Food Store #2 / Iowa City
# 5 S29050800001        11/17/2015 3942         Twin Town Liquor
# 6 S28869200001        11/11/2015 3650         Spirits, Stogies and Stuff
#   Address             City         Zip Code
# 1 1013 MAIN           KEOKUK       52632
# 2 900 E WASHINGTON    CLARINDA     51632
# 3 1414 48TH ST        FORT MADISON 52627
# 4 812  S 1ST AVE      IOWA CITY    52240
# 5 104 HIGHWAY 30 WEST TOLEDO       52342
# 6 118 South Main St.  HOLSTEIN     51025
#   Store Location                                          County Number County
# 1 1013 MAINKEOKUK 52632(40.39978, -91.387531)             56            Lee
# 2 900 E WASHINGTONCLARINDA 51632(40.739238, -95.02756)    73            Page
# 3 1414 48TH STFORT MADISON 52627(40.624226, -91.373211)   56            Lee
# 4 812 S 1ST AVEIOWA CITY 52240                            52            Johnson
# 5 104 HIGHWAY 30 WESTTOLEDO 52342(41.985887, -92.579244)  86            Tama
# 6 118 South Main St.HOLSTEIN 51025(42.490073, -95.544793) 47            Ida
#   ... Bottle Volume (ml) State Bottle Cost State Bottle Retail Bottles Sold
# 1 ...  750               $18.09            $27.14               6
# 2 ...  750               $18.09            $27.14              12
# 3 ...  150               $6.40             $9.60                2
# 4 ... 1750               $35.55            $53.34               3
# 5 ...  150               $6.40             $9.60                2
# 6 ... 1750               $35.55            $53.34               1
#   Sale (Dollars) Volume Sold (Liters) Volume Sold (Gallons) date_b     month_b
# 1 $162.84        4.50                 1.19                  2015-11-20 11
# 2 $325.68        9.00                 2.38                  2015-11-21 11
# 3 $19.20         0.30                 0.08                  2015-11-16 11
# 4 $160.02        5.25                 1.39                  2015-11-04 11
# 5 $19.20         0.30                 0.08                  2015-11-17 11
# 6 $53.34         1.75                 0.46                  2015-11-11 11
#   year_b
# 1 2015
# 2 2015
# 3 2015
# 4 2015
# 5 2015
# 6 2015

# %% [markdown]
# I got the same result as previous questions. I prefer lubridate package because it is always good to simplify the code.

# %% [markdown]
# ## Question 4

# %%
tapply(liquor$'Volume Sold (Gallons)', liquor$month, mean)
# Out:
#       01       02       03       04       05       06       07       08
# 2.244268 2.402956 2.260505 2.406334 2.455314 2.454127 2.259348 2.332155
#       09       10       11       12
# 2.354165 2.947077 2.259482 2.257290

# %%
plot(tapply(liquor$'Volume Sold (Gallons)', liquor$month, mean), xaxt="n")
axis(side=1, at=1:12, labels=month.abb)
# Out:
# plot without title

# %% [markdown]
# As we can see, January has the lowest average sold per month. This is a little bit surprising because the temperature in Jan is extremely cold so liquor should be in great need.

# %% [markdown]
# ## Question 5

# %%
myDF <- tapply(liquor$'Volume Sold (Gallons)', list(liquor$month, liquor$year), mean)

# %%
head(myDF)
# Out:
#    2012     2013     2014     2015
# 01 2.164335 2.152848 2.456344 2.201005
# 02 2.348675 2.319316 2.447075 2.494598
# 03 2.240106 2.206151 2.278171 2.310022
# 04 2.390600 2.451803 2.445837 2.337234
# 05 2.347184 2.507527 2.468052 2.510394
# 06 2.540984 2.396912 2.459515 2.421554

# %%
plot(myDF[, 1], xaxt="n", col="red", type="b", xlab="Month", ylab="Sale")
axis(side=1, at=1:12, labels=month.abb)
lines(myDF[, 2], col="blue", type="b")
lines(myDF[, 3], col="green", type="b")
lines(myDF[, 4], col="black", type="b")
legend("top", legend=c("2012","2013","2014","2015"), col=c("red","blue","green","black"), lty=1 )
# Out:
# plot without title

# %% [markdown]
# As we can see, For different years, the trend of sale of liquor is different with respect to months. Especially in October, the data from 2012 and 2013 are very close, while the data from 2014 and 2015 are very close. Maybe 2014 is a turning point.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
